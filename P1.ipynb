# %% [markdown]
# ![image.png]()![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib import pyplot
from sklearn.model_selection import train_test_split, cross_val_score, RepeatedKFold

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---
#
#
# # EDA:
#
#
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
#
#
# df.sample(3)
#
# df.shape
#
# df.isnull().sum().sum()
#
# df.size
#
# df.dtypes
#
# df['C'].unique()
#
# df.describe()
#
# df['C'].nunique()
#
# df['C'].is_monotonic_increasing
#
# df['C'].value_counts(normalize=True)
#
# df['C'].nsmallest(3)
#
# df['C'].nlargest(3)
#
# df.corr()
#
# df.plot(x='C1', y='C2'kind='scatter')
# df['C'].plot(kind='hist')

# %%
df=pd.read_csv('HR_comma_sep.csv')

# %%
df
# Out:
#       satisfaction_level;last_evaluation;number_project;average_montly_hours;time_spend_company;Work_accident;left;promotion_last_5years;sales;salary
# 0                      0.38;0.53;2;157;3;0;1;0;sales;low
# 1                    0.8;0.86;5;262;6;0;1;0;sales;medium
# 2                   0.11;0.88;7;272;4;0;1;0;sales;medium
# 3                      0.72;0.87;5;223;5;0;1;0;sales;low
# 4                      0.37;0.52;2;159;3;0;1;0;sales;low
# ...                                                  ...
# 14994                 0.4;0.57;2;151;3;0;1;0;support;low
# 14995                0.37;0.48;2;160;3;0;1;0;support;low
# 14996                0.37;0.53;2;143;3;0;1;0;support;low
# 14997                0.11;0.96;6;280;4;0;1;0;support;low
# 14998                0.37;0.52;2;158;3;0;1;0;support;low
#
# [14999 rows x 1 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.shape
# Out:
# (14999, 1)

# %%
df.dtypes
# Out:
# satisfaction_level;last_evaluation;number_project;average_montly_hours;time_spend_company;Work_accident;left;promotion_last_5years;sales;salary    object
# dtype: object

# %%
df.isna().sum()
# Out:
# satisfaction_level;last_evaluation;number_project;average_montly_hours;time_spend_company;Work_accident;left;promotion_last_5years;sales;salary    0
# dtype: int64

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of       satisfaction_level;last_evaluation;number_project;average_montly_hours;time_spend_company;Work_accident;left;promotion_last_5years;sales;salary
# 0                      0.38;0.53;2;157;3;0;1;0;sales;low
# 1                    0.8;0.86;5;262;6;0;1;0;sales;medium
# 2                   0.11;0.88;7;272;4;0;1;0;sales;medium
# 3                      0.72;0.87;5;223;5;0;1;0;sales;low
# 4                      0.37;0.52;2;159;3;0;1;0;sales;low
# ...                                                  ...
# 14994                 0.4;0.57;2;151;3;0;1;0;support;low
# 14995                0.37;0.48;2;160;3;0;1;0;support;low
# 14996                0.37;0.53;2;143;3;0;1;0;support;low
# 14997                0.11;0.96;6;280;4;0;1;0;support;low
# 14998                0.37;0.52;2;158;3;0;1;0;support;low
#
# [14999 rows x 1 columns]>

# %%
df.isnull().sum()
# Out:
# satisfaction_level;last_evaluation;number_project;average_montly_hours;time_spend_company;Work_accident;left;promotion_last_5years;sales;salary    0
# dtype: int64

# %%
df.left.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-5eb53e9785a3> in <cell line: 1>()
# ----> 1 df.left.value_counts()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'left'

# %%
# Display the mean summary of Employees
left_Summary = df.groupby('left')
print(left_Summary.mean(), 2)
print('-----------------------------------------------------------')
print(left_Summary.std(), 2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-4054b4171833> in <cell line: 2>()
#       1 # Display the mean summary of Employees
# ----> 2 left_Summary = df.groupby('left')
#       3 print(left_Summary.mean(), 2)
#       4 print('-----------------------------------------------------------')
#       5 print(left_Summary.std(), 2)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8400         axis = self._get_axis_number(axis)
#    8401
# -> 8402         return DataFrameGroupBy(
#    8403             obj=self,
#    8404             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
# ...

# %%
plt.figure(figsize=(20,8))
ax = sns.barplot(x="left", y="satisfaction_level", hue="left", data=df)
ax.set(ylabel="Percent");
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-e95a49b978d8> in <cell line: 2>()
#       1 plt.figure(figsize=(20,8))
# ----> 2 ax = sns.barplot(x="left", y="satisfaction_level", hue="left", data=df)
#       3 ax.set(ylabel="Percent");
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2753         estimator = "size"
#    2754
# -> 2755     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                           estimator, errorbar, n_boot, units, seed,
#    2757                           orient, color, palette, saturation,
#
# ...

# %%
plt.figure(figsize=(20,8))
ax = sns.barplot(x="number_project", y="number_project", hue="left", data=df, estimator=lambda x: len(x) / len(df) * 100)
ax.set(ylabel="Percent");

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# heatmap
corr = df.corr()
plt.figure(figsize=(12,10))
sns.heatmap(corr,cmap=plt.cm.CMRmap_r,annot=True)
plt.show()
# Out:
# <ipython-input-18-925c41224fb0>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-925c41224fb0> in <cell line: 4>()
#       2 corr = df.corr()
#       3 plt.figure(figsize=(12,10))
# ----> 4 sns.heatmap(corr,cmap=plt.cm.CMRmap_r,annot=True)
#       5 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     444     """
#     445     # Initialize the plotter object
# ...

# %%
plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(df.corr()[['left']].sort_values(by='left', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with left', fontdict={'fontsize':18}, pad=16);
# Out:
# <ipython-input-14-a6f2c96a9ce7>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap = sns.heatmap(df.corr()[['left']].sort_values(by='left', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')

# %%
# Graph Employee Satisfaction
sns.distplot(df.satisfaction_level)
# Out:
# <ipython-input-15-94f7efff829d>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.satisfaction_level)
# <Axes: xlabel='satisfaction_level', ylabel='Density'>

# %%
# Graph Employee Evaluation
sns.distplot(df.last_evaluation);
# Out:
# <ipython-input-16-25ecc20c93ef>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.last_evaluation);

# %%
# Graph Employee Average Monthly Hours
sns.distplot(df.average_montly_hours);
# Out:
# <ipython-input-17-a42b9b764e4b>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.average_montly_hours);

# %%
plt.figure(figsize=(12,8))
left = df.left.value_counts()
sns.barplot(y=left.values, x=left.index, alpha=0.6)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 3
# ![image.png](data:image/png;base64,...)

# %%
# Import KMeans Model
from sklearn.cluster import KMeans

# call the model
kmeans = KMeans(n_clusters=3,random_state=0)


# train the model
kmeans.fit(df[df.left==1][["satisfaction_level","last_evaluation"]])
kmeans_colors = ['pink' if c == 0 else 'gold' if c == 2 else 'maroon' for c in kmeans.labels_]

# visualized
plt.scatter(x="satisfaction_level",y="last_evaluation", data=df[df.left==1], alpha=0.25,color=kmeans_colors)
plt.xlabel("satisfaction_level")
plt.ylabel("last_evaluation")
plt.scatter(x=kmeans.cluster_centers_[:,0],y=kmeans.cluster_centers_[:,1],marker="+",s=100)
plt.title("Clusters of Employee left")
plt.show();
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# # 4
# ![image.png](data:image/png;base64,...)

# %%
num=df[['satisfaction_level','last_evaluation','number_project','average_montly_hours','time_spend_company','Work_accident','left','promotion_last_5years']]
#cat=df['sales','salary']

X=pd.get_dummies(df,columns=['salary','sales'],drop_first=True, dummy_na=True)
#X= X.astype(int)
df_N = pd.concat([num,X])
df_N.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# salary_low               float64
# salary_medium            float64
# salary_nan               float64
# sales_RandD              float64
# sales_accounting         float64
# sales_hr                 float64
# sales_management         float64
# sales_marketing          float64
# sales_product_mng        float64
# sales_sales              float64
# sales_support            float64
# sales_technical          float64
# sales_nan                float64
# dtype: object

# %%
df_N.isnull().sum()
# Out:
# satisfaction_level           0
# last_evaluation              0
# number_project               0
# average_montly_hours         0
# time_spend_company           0
# Work_accident                0
# left                         0
# promotion_last_5years        0
# salary_low               14999
# salary_medium            14999
# salary_nan               14999
# sales_RandD              14999
# sales_accounting         14999
# sales_hr                 14999
# sales_management         14999
# sales_marketing          14999
# sales_product_mng        14999
# sales_sales              14999
# sales_support            14999
# sales_technical          14999
# sales_nan                14999
# dtype: int64

# %%
df_N.fillna(0, inplace = True)

# %%
df_N.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# salary_low               0
# salary_medium            0
# salary_nan               0
# sales_RandD              0
# sales_accounting         0
# sales_hr                 0
# sales_management         0
# sales_marketing          0
# sales_product_mng        0
# sales_sales              0
# sales_support            0
# sales_technical          0
# sales_nan                0
# dtype: int64

# %%
#df_n=df_N.astype(int)
# Create the X and y set
x = df_N.iloc[:,1:]
y = df_N.iloc[:,6]

# %%
#from sklearn.utils import resample
#from imblearn.over_sampling import SMOTE


# Upsample using SMOTE
#sm = SMOTE()
#x_rs,y_rs = sm.fit_resample(x,y)

#print("Original shape:", x.shape, y.shape)
#print ("SMOTE sample shape:",x_rs.shape,y_rs.shape)

# %%
from sklearn.utils import resample
from imblearn.over_sampling import SMOTE


# Upsample using SMOTE
sm = SMOTE()
x_rs,y_rs = sm.fit_resample(x,y)

print("Original shape:", x.shape, y.shape)
print ("SMOTE sample shape:",x_rs.shape,y_rs.shape)
# Out:
# Original shape: (29998, 20) (29998,)
# SMOTE sample shape: (45712, 20) (45712,)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn import metrics
from sklearn.metrics import classification_report

# %%
x_train,x_test, y_train, y_test = train_test_split(x, y, test_size=0.20,random_state=123)

# %% [markdown]
# # LogisticRegression

# %%
lr = LogisticRegression()
lr = lr.fit(x_train, y_train)
y_predf = lr.predict(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
lr_auc = roc_auc_score(y_test, lr.predict(x_test))
print(lr_auc)

print(classification_report(y_test, y_predf))
# Out:
# 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4594
#            1       1.00      1.00      1.00      1406
#
#     accuracy                           1.00      6000
#    macro avg       1.00      1.00      1.00      6000
# weighted avg       1.00      1.00      1.00      6000

# %%
lr_result = cross_val_score(lr, x_train, y_train, cv=5, scoring='f1')
y_pred = lr.predict(x_test)
lr_result.mean()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4594
#            1       1.00      1.00      1.00      1406
#
#     accuracy                           1.00      6000
#    macro avg       1.00      1.00      1.00      6000
# weighted avg       1.00      1.00      1.00      6000

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()

rf.fit(x_train, y_train)

pred_rf = rf.predict(x_test)

# %%
rf_roc_auc = roc_auc_score(y_test, rf.predict(x_test))
print(rf_roc_auc)

print(classification_report(y_test, pred_rf))
# Out:
# 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4594
#            1       1.00      1.00      1.00      1406
#
#     accuracy                           1.00      6000
#    macro avg       1.00      1.00      1.00      6000
# weighted avg       1.00      1.00      1.00      6000

# %%
rf_result = cross_val_score(rf, x_train, y_train, cv=5, scoring='f1')
y_predrf = rf.predict(x_test)
rf_result.mean()
# Out:
# 1.0

# %%
print(classification_report(y_test, y_predrf))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4594
#            1       1.00      1.00      1.00      1406
#
#     accuracy                           1.00      6000
#    macro avg       1.00      1.00      1.00      6000
# weighted avg       1.00      1.00      1.00      6000

# %% [markdown]
# # GradientBoostingClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbc = GradientBoostingClassifier()
gbc = gbc.fit(x_train,y_train)
pred_gbc = rf.predict(x_test)

# %%
gbc_auc = roc_auc_score(y_test, gbc.predict(x_test))
print(gbc_auc)
print(classification_report(y_test, pred_gbc))
# Out:
# 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4594
#            1       1.00      1.00      1.00      1406
#
#     accuracy                           1.00      6000
#    macro avg       1.00      1.00      1.00      6000
# weighted avg       1.00      1.00      1.00      6000

# %%
gbc_result = cross_val_score(gbc, x_train, y_train, cv=5, scoring='f1')
y_predrgbc = gbc.predict(x_test)
gbc_result.mean()
# Out:
# 1.0

# %%
print(classification_report(y_test, y_predrgbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4594
#            1       1.00      1.00      1.00      1406
#
#     accuracy                           1.00      6000
#    macro avg       1.00      1.00      1.00      6000
# weighted avg       1.00      1.00      1.00      6000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#An ROC curve (receiver operating characteristic curve) is a graph showing the performance of a
#classification model at all classification thresholds. This curve plots two parameters:

#True Positive Rate
#False Positive Rate

#AUC stands for "Area under the ROC Curve." That is, AUC measures the entire
#two-dimensional area underneath the entire ROC curve (think integral calculus) from (0,0) to (1,1).

# Create ROC Graph
from sklearn.metrics import roc_curve
from sklearn.metrics import confusion_matrix

fpr, tpr, thresholds = roc_curve(y_test, lr.predict_proba(x_test)[:,1])
rf_fpr, rf_tpr, rf_thresholds = roc_curve(y_test, rf.predict_proba(x_test)[:,1])
gbc_fpr, gbc_tpr, gbc_thresholds = roc_curve(y_test, gbc.predict_proba(x_test)[:,1])


plt.figure(figsize=(15,12))

# Plot Logistic Regression ROC
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % lr_auc)

# Plot Random Forest ROC
plt.plot(rf_fpr, rf_tpr, label='Random Forest Classifier (area = %0.2f)' % rf_roc_auc)

# Plot Decision Tree ROC
plt.plot(gbc_fpr, gbc_tpr, label='Gradient Boosting Classifier (area = %0.2f)' % gbc_auc)

# Plot Base Rate ROC
plt.plot([0,1], [0,1],label='Base Rate')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Graph')
plt.legend(loc="lower right")
plt.show();

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Load the model and make predictions on the test data
model = load_model('employee_turnover_model.h5')
predictions = model.predict_proba(test_data)

# Create a DataFrame to store the results
results = pd.DataFrame()
results['EmployeeID'] = test_data['EmployeeID']
results['Probability'] = predictions[:, 1]  # Assuming the second column contains the probability of turnover

# Categorize employees into different zones
results['Zone'] = pd.cut(results['Probability'], bins=[0, 0.2, 0.6, 0.9, 1], labels=['Safe Zone', 'Low Risk Zone', 'Medium Risk Zone', 'High Risk Zone'])

# Print the results
print(results)

# Retention strategies for each zone
safe_zone_employees = results[results['Zone'] == 'Safe Zone']
low_risk_zone_employees = results[results['Zone'] == 'Low Risk Zone']
medium_risk_zone_employees = results[results['Zone'] == 'Medium Risk Zone']
high_risk_zone_employees = results[results['Zone'] == 'High Risk Zone']

print("Retention strategies for Safe Zone employees:")
# Add your suggestions for retaining employees in the Safe Zone

print("Retention strategies for Low Risk Zone employees:")
# Add your suggestions for retaining employees in the Low Risk Zone

print("Retention strategies for Medium Risk Zone employees:")
# Add your suggestions for retaining employees in the Medium Risk Zone

print("Retention strategies for High Risk Zone employees:")
# Add your suggestions for retaining employees in the High Risk Zone
